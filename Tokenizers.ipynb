# %%
# !pip install transformers
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
print(tokenizer.vocab)
# Out:
# {'ritch': 46510, 'formation': 1161, 'Ġclasses': 6097, 'ĠOmar': 24980, 'ĠEm': 2295, 'ĠHom': 8074, 'Ġprotagonist': 20281, 'ĠRegulations': 26108, 'ĠHuckabee': 38253, 'Dialogue': 41099, 'Ġchipset': 49013, 'detail': 49170, 'ĠCu': 14496, 'ĠHPV': 32395, 'Ġbrittle': 49307, 'ĠAnnual': 16328, '378': 30695, 'Ġseal': 13810, 'Ġimposing': 20814, 'ß': 155, '¹': 117, 'Ġparcel': 25232, 'ĠMemor': 41157, 'Ġhypothetical': 25345, 'Ġdarts': 47807, 'Ġfingers': 9353, 'imon': 20473, 'Ġblitz': 32528, 'hyper': 49229, 'Ġconversations': 10275, 'ĠCore': 7231, 'Configuration': 38149, '578': 38907, 'ĠrÃ©': 40560, '".[': 42924, 'Ġboon': 38181, 'ĠKabul': 34753, 'Ġpearl': 43836, 'yu': 24767, 'ighters': 6261, 'rium': 19172, 'ĠPredator': 38871, 'ĠNottingham': 39802, 'Relations': 47117, 'Ġ399': 43927, 'ĠEAR': 31834, 'orph': 13425, 'Explore': 35433, 'Ġentangled': 47446, 'Ġlower': 2793, 'ĠNeither': 16126, 'Ġdst': 29636, 'Ġstitches': 28096, 'ĠLabour': 7179, 'elong': 21537, 'Ġinventions': 39405, 'Ġweight': 3463, 'Ġgeographic
# ...

# %%
#code sample will use the tokenizer object to convert a sentence into tokens and IDs.
token_ids = tokenizer.encode("This is a sample text to test the tokenizer.")
print("Tokens:  ", tokenizer.convert_ids_to_tokens(token_ids))
print("Token IDs:" , token_ids)
# Out:
# Tokens:   ['This', 'Ġis', 'Ġa', 'Ġsample', 'Ġtext', 'Ġto', 'Ġtest', 'Ġthe', 'Ġtoken', 'izer', '.']
# Token IDs: [1212, 318, 257, 6291, 2420, 284, 1332, 262, 11241, 7509, 13]
